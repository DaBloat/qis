# %%
import qutip as qp
import numpy as np

# %%
b = qp.Bloch()

# %%
A = np.array([[1],[0]])

# %%
b.add_states([qp.Qobj(A)])

# %%
b.show()

# %%
b.clear()

# %%
from qutip_qip.operations import *

# %%
P = np.array([[0],[1]])
print(H(0).get_compact_qobj() @ P)
# Out:
# Quantum object: dims=[[2], [1]], shape=(2, 1), type='ket', dtype=Dense
# Qobj data =
# [[ 0.70710678]
#  [-0.70710678]]

# %%
b.add_states([H(0).get_compact_qobj()])

# %%
b.show()

# %%
H(0).get_compact_qobj()
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[ 0.70710678  0.70710678]
#  [ 0.70710678 -0.70710678]]

# %%
Y(0).get_compact_qobj()
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0.+0.j 0.-1.j]
#  [0.+1.j 0.+0.j]]

# %%
Y(0).get_compact_qobj()
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0.+0.j 0.-1.j]
#  [0.+1.j 0.+0.j]]

# %%
Z(0).get_compact_qobj()
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[ 1.  0.]
#  [ 0. -1.]]

# %%
b.add_states([S(0).get_compact_qobj() @ P])

# %%
b.show()

# %%
b.clear()

# %%
b.add_states([T(0).get_compact_qobj() @ P])
b.show()

# %%
b.clear()
b.add_states([RX(0, np.pi/2).get_compact_qobj() @ P])
b.show()

# %%
b.clear()
b.add_states([RY(0, np.pi/2).get_compact_qobj() @ P])
b.show()

# %%
b.clear()
b.add_states([RZ(0, np.pi/2).get_compact_qobj() @ P])
b.show()

# %%
b.clear()
b.show()

# %%
b.clear()

# %%
Q = H(0).get_compact_qobj() @ P
Q
# Out:
# Quantum object: dims=[[2], [1]], shape=(2, 1), type='ket', dtype=Dense
# Qobj data =
# [[ 0.70710678]
#  [-0.70710678]]

# %%
R = H(0).get_compact_qobj() @ Q
R
# Out:
# Quantum object: dims=[[2], [1]], shape=(2, 1), type='ket', dtype=Dense
# Qobj data =
# [[0.]
#  [1.]]

# %%
b.add_states([qp.Qobj(P)])

# %%
b.add_states([qp.Qobj(Q)])

# %%
b.show()

# %%
b.clear()
b.add_states([qp.Qobj(R)])
b.show()

# %%
b.clear()
b.add_states([qp.Qobj(P)])
b.show()

# %%
o = Y(0).get_compact_qobj() @ qp.Qobj(P)
b.add_states([o])
b.show()

# %%
b.add_states([RZ(0, np.pi/2).get_compact_qobj() @ o])
b.show()

# %%
b.add_states([T(0).get_compact_qobj() @ o])
b.show()

# %%
b.add_states([T(0).get_compact_qobj() @ o])
b.show()
